# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# the basic EDA (Exploratory Data Analysis)

# %%
ticker = "AAPL"

df = yf.download(
    ticker,
    start="2020-01-01",
    end="2026-01-01"
)

df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.333870  72.394078  71.091176  71.344047  135480400
# 2020-01-03  71.630646  72.389265  71.406674  71.563213  146322800
# 2020-01-06  72.201408  72.239942  70.503546  70.754014  118387200
# 2020-01-07  71.861847  72.466330  71.642689  72.211049  108872000
# 2020-01-08  73.017830  73.318870  71.565614  71.565614  132079200

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 1508 entries, 2020-01-02 to 2025-12-31
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   1508 non-null   float64
#  1   (High, AAPL)    1508 non-null   float64
#  2   (Low, AAPL)     1508 non-null   float64
#  3   (Open, AAPL)    1508 non-null   float64
#  4   (Volume, AAPL)  1508 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 70.7 KB

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   AAPL      0
# High    AAPL      0
# Low     AAPL      0
# Open    AAPL      0
# Volume  AAPL      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Average stock price = 150
#Highest stock price = 260
#Lowest stock price = 70
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker         AAPL         AAPL         AAPL         AAPL          AAPL
# count   1508.000000  1508.000000  1508.000000  1508.000000  1.508000e+03
# mean     164.635762   166.317006   162.788386   164.474886  8.453734e+07
# std       49.626455    49.917229    49.286415    49.583376  5.136424e+07
# min       54.163708    55.160705    51.324804    55.059316  1.791060e+07
# 25%      131.178299   132.636094   129.816892   131.583395  5.075645e+07
# 50%      163.044128   165.172212   161.770225   163.302214  7.040210e+07
# 75%      197.198059   199.120393   194.347201   196.560463  1.005718e+08
# max      285.659271   288.084759   282.774617   285.669263  4.265100e+08

# %%
#This shows the stock's price movement over time.
plt.plot(df['Close'])
